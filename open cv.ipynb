# %%
import cv2

# %%
img = cv2.imread("C:/Users/tarak/Downloads/download.jpg")

# %%
cv2.imshow('image',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
newImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newImg)
plt.show()

# %%
gray = cv2.imread("C:/Users/tarak/Downloads/download.jpg",cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('gray',gray)#Wait for any key before image disappears
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img)
# Out:
# [[[27  4 36]
#   [31  9 38]
#   [36 14 42]
#   ...
#   [33 14 11]
#   [33 14 11]
#   [34 15 12]]
#
#  [[24  2 30]
#   [26  5 30]
#   [30 11 32]
#   ...
#   [33 13 12]
#   [33 13 12]
#   [35 15 14]]
#
#  [[22  4 21]
#   [24  7 21]
#   [26  9 22]
#   ...
#   [32 11 14]
#   [34 13 16]
#   [37 16 19]]
#
#  ...
#
#  [[ 6  4  4]
#   [ 6  4  4]
#   [ 6  4  4]
#   ...
#   [ 0  5  4]
#   [ 0  5  4]
#   [ 0  5  4]]
#
#  [[ 6  4  4]
#   [ 6  4  4]
#   [ 6  4  4]
#   ...
#   [ 0  5  4]
#   [ 0  5  4]
#   [ 0  5  4]]
#
#  [[ 4  4  4]
#   [ 4  4  4]
#   [ 4  4  4]
#   ...
#   [ 0  5  4]
#   [ 0  5  4]
#   [ 0  5  4]]]

# %%
print(newImg)
# Out:
# [[[36  4 27]
#   [38  9 31]
#   [42 14 36]
#   ...
#   [11 14 33]
#   [11 14 33]
#   [12 15 34]]
#
#  [[30  2 24]
#   [30  5 26]
#   [32 11 30]
#   ...
#   [12 13 33]
#   [12 13 33]
#   [14 15 35]]
#
#  [[21  4 22]
#   [21  7 24]
#   [22  9 26]
#   ...
#   [14 11 32]
#   [16 13 34]
#   [19 16 37]]
#
#  ...
#
#  [[ 4  4  6]
#   [ 4  4  6]
#   [ 4  4  6]
#   ...
#   [ 4  5  0]
#   [ 4  5  0]
#   [ 4  5  0]]
#
#  [[ 4  4  6]
#   [ 4  4  6]
#   [ 4  4  6]
#   ...
#   [ 4  5  0]
#   [ 4  5  0]
#   [ 4  5  0]]
#
#  [[ 4  4  4]
#   [ 4  4  4]
#   [ 4  4  4]
#   ...
#   [ 4  5  0]
#   [ 4  5  0]
#   [ 4  5  0]]]

# %%
# Read a Video Stream from Camera (Frame by Frame)

import cv2

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    if ret == False:
        continue

    cv2.imshow("Video Frame", frame)
    cv2.imshow("Gray Frame", gray_frame)
    
    #Wait for user input- q, then you will stop the loop 
    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed == ord('q'):
        break


cap.release()
cv2.destroyAL1Windows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       5 cap = cv2.VideoCapture(0)
#       7 while True:
# ----> 8     ret, frame = cap.read()
#       9     gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      10     if ret == False:
#
# KeyboardInterrupt:
